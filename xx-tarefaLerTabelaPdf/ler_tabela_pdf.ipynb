# %%
import tabula
import pandas as pd

col_areas=[(202.455,3.63,432.135,77.88),(200.475,79.86,430.155,92.73),(201.465,94.71,430.155,256.08),(200.475,258.06,430.155,303.6),(201.465,302.61,432.135,348.15),(199.485,349.14,432.135,365.97),(200.475,366.96,430.155,385.77),(200.475,384.78,431.145,502.59),(199.485,503.58,432.135,522.39),(201.465,521.4,430.155,576.84),(200.475,576.84,432.135,594.66),(200.475,594.66,432.135,618.42),(198.495,617.43,432.135,646.14),(200.475,646.14,430.155,695.64)]

def ler_pdf_padrao(path):
    tabela=pd.DataFrame()
    for col in col_areas:
        col1=tabula.read_pdf(path,pages=1,area=col,stream=True)
        col1=col1[0]
        col1=pd.DataFrame(col1)
        tabela= pd.concat([tabela, col1], ignore_index=False,axis=1)
        
    return tabela


display(ler_pdf_padrao('teste.pdf'))
# Out:
#    Component P/N Re                Component Description Reqmt Qty Quantity  \
# 0    P1000031620  D  KEY, ANTI-ROTATION, 5-15K TORUS IV     1,000    1,000
# 1    P1000085812  C  CAP SCREW, HEX SOCKET DRIVE, .375-     4,000    4,000
# 2    P1000108405  G  OBSOLETE AND REPLACED BY P20000817     0,000    0,000
# 3    P1000164188  B  GV SEAT KIT, M131, 5 1/8-10K, P-X,     2,000    0,000
# 4    P1000164189  E  GV SEAT, M131, 5 1/8-10K, K-X, PSL     2,000    1,000
# 5    P1000164189  E  GV SEAT, M131, 5 1/8-10K, K-X, PSL     0,000    1,000
# 6    P1000164192  D  GV GATE GUIDE, M131, 5 1/8-10K, NI     2,000    2,000
# 7    P1000164197  D  GV GATE M131, 5 1/8-10K, NI ALLOY,     1,000    1,000
# 8    P1000164208  E  GV STEM KIT M131, 5 1/8-10K, ACTUA     1,000    1,000
# 9    P1000164780  A  METAL SPRING ENERGIZED U-CUP SEAL      2,000    2,000
# 10   P1000164784  B  NON METALLIC SEAL, FACE SEAL F/ M1     2,000    2,000
# 11   P1000167169  A  GV DRIFT ADJUSTMENT NUT SUBSEA, M3     1,000    1,000
#
#     BUn  Ser   Component Serial  BMR       Batch  Pha  Act. Doc.  Source Bin
# 0    EA  NaN                NaN  NaN         NaN  NaN     1  NaN  D-048-06-2
# 1    EA  NaN                NaN    X       10763  NaN     1  FRC  GC-03-02-1
# 2    EA  NaN                NaN  NaN         NaN  NaN     1  NaN         NaN
# 3    EA  NaN                NaN  NaN         NaN    X     1  NaN         NaN
# 4    EA    X   4500612970-40-84  NaN         NaN  NaN     1  FRC  D-008-03-1
# 5   NaN    X   4500612970-70-76  NaN         NaN  NaN     1  FRC  D-008-03-1
# 6    EA  NaN                NaN    X   328061010  NaN     1  FRC  C-020-04-1
# 7    EA    X   4500612972-80-14  NaN         NaN  NaN     1  FRC  A-068-06-2
# 8    EA    X  4500586965-180-25  NaN         NaN  NaN     1  FRC  D-033-08-1
# 9    EA  NaN                NaN    X     1715455  NaN     1  FRC  RG-10-01-1
# 10   EA  NaN                NaN    X  2022.07.01  NaN     1  FRC  RD-15-01-1
# 11   EA  NaN                NaN  NaN         NaN  NaN     1  NaN  B-071-04-2
